# %%
import os
import shutil
import random

# Define paths
base_dir = "vehicle"
train_images_dir = os.path.join(base_dir, "train", "images")
train_labels_dir = os.path.join(base_dir, "train", "labels")

valid_images_dir = os.path.join(base_dir, "valid", "images")
valid_labels_dir = os.path.join(base_dir, "valid", "labels")
test_images_dir = os.path.join(base_dir, "test", "images")
test_labels_dir = os.path.join(base_dir, "test", "labels")

# Ensure directories exist
os.makedirs(valid_images_dir, exist_ok=True)
os.makedirs(valid_labels_dir, exist_ok=True)
os.makedirs(test_images_dir, exist_ok=True)
os.makedirs(test_labels_dir, exist_ok=True)

# List all images
all_images = sorted(os.listdir(train_images_dir))
random.shuffle(all_images)  # Shuffle for randomness

# Split dataset (10% validation, 10% test)
num_valid = len(all_images) // 10  
num_test = len(all_images) // 10  

valid_images = all_images[:num_valid]
test_images = all_images[num_valid:num_valid + num_test]

# Move images & labels to valid/
for img_name in valid_images:
    img_path = os.path.join(train_images_dir, img_name)
    label_path = os.path.join(train_labels_dir, img_name.replace(".jpg", ".txt"))

    if os.path.exists(img_path):
        shutil.move(img_path, valid_images_dir)
    if os.path.exists(label_path):
        shutil.move(label_path, valid_labels_dir)

# Move images & labels to test/
for img_name in test_images:
    img_path = os.path.join(train_images_dir, img_name)
    label_path = os.path.join(train_labels_dir, img_name.replace(".jpg", ".txt"))

    if os.path.exists(img_path):
        shutil.move(img_path, test_images_dir)
    if os.path.exists(label_path):
        shutil.move(label_path, test_labels_dir)

print("✅ Data moved successfully!")
# Out:
# ✅ Data moved successfully!

# %% [markdown]
# #if you have only tain then it will split valid and test

# %%
import os
import shutil

# Define paths
base_dir = "vehicle"
train_labels_dir = os.path.join(base_dir, "train", "labels")
train_images_dir = os.path.join(base_dir, "train", "images")

valid_dir = os.path.join(base_dir, "valid")
test_dir = os.path.join(base_dir, "test")

valid_labels_dir = os.path.join(valid_dir, "labels")
valid_images_dir = os.path.join(valid_dir, "images")
test_labels_dir = os.path.join(test_dir, "labels")
test_images_dir = os.path.join(test_dir, "images")

# Create valid and test folders
os.makedirs(valid_labels_dir, exist_ok=True)
os.makedirs(valid_images_dir, exist_ok=True)
os.makedirs(test_labels_dir, exist_ok=True)
os.makedirs(test_images_dir, exist_ok=True)

# Process label files: Change all class IDs to 6
for label_file in os.listdir(train_labels_dir):
    label_path = os.path.join(train_labels_dir, label_file)

    with open(label_path, "r") as f:
        lines = f.readlines()

    new_lines = []
    for line in lines:
        parts = line.strip().split()
        parts[0] = "6"  # Change ALL class IDs to 6 (Vehicle)
        new_lines.append(" ".join(parts) + "\n")

    # Save modified labels
    with open(label_path, "w") as f:
        f.writelines(new_lines)

# Move 10% of data to valid & test folders
all_images = sorted(os.listdir(train_images_dir))
num_valid = len(all_images) // 10  # 10% for validation
num_test = len(all_images) // 10  # 10% for testing

valid_images = all_images[:num_valid]
test_images = all_images[num_valid:num_valid + num_test]

for img_name in valid_images:
    img_path = os.path.join(train_images_dir, img_name)
    label_path = os.path.join(train_labels_dir, img_name.replace(".jpg", ".txt"))  # Assuming JPG format

    shutil.move(img_path, valid_images_dir)
    if os.path.exists(label_path):
        shutil.move(label_path, valid_labels_dir)

for img_name in test_images:
    img_path = os.path.join(train_images_dir, img_name)
    label_path = os.path.join(train_labels_dir, img_name.replace(".jpg", ".txt"))

    shutil.move(img_path, test_images_dir)
    if os.path.exists(label_path):
        shutil.move(label_path, test_labels_dir)

print("✅ All class IDs changed to 6 (Vehicle), and dataset split into train, valid, and test.")
# Out:
# ✅ All class IDs changed to 6 (Vehicle), and dataset split into train, valid, and test.

# %% [markdown]
# #for individual folder to change class id

# %%
import os

# Define paths
base_dir = "CrossWalk_Copy"  # Update if needed
folders = ["train", "valid", "test"]

for folder in folders:
    labels_dir = os.path.join(base_dir, folder, "labels")

    # Check if labels directory exists
    if not os.path.exists(labels_dir):
        print(f"❌ Labels folder missing: {labels_dir}")
        continue  # Skip if folder doesn't exist

    # Process each label file
    for label_file in os.listdir(labels_dir):
        label_path = os.path.join(labels_dir, label_file)

        if label_file.endswith(".txt"):
            with open(label_path, "r") as f:
                lines = f.readlines()

            # Replace all class IDs with 0
            updated_lines = ["2 " + " ".join(line.split()[1:]) + "\n" for line in lines]

            # Save back the modified labels
            with open(label_path, "w") as f:
                f.writelines(updated_lines)

            print(f"✅ Updated: {label_path}")

print("🎯 All labels updated successfully!")
# Out:
# ✅ Updated: CrossWalk_Copy\train\labels\101_jpg.rf.1935f8fb6ed15d064db90efabfceb986.txt
# ✅ Updated: CrossWalk_Copy\train\labels\101_jpg.rf.1af4e33116c43a580a0eb5d85e36990b.txt
# ✅ Updated: CrossWalk_Copy\train\labels\101_jpg.rf.65ad96a1270cd83af1f7319ee1bf24de.txt
# ✅ Updated: CrossWalk_Copy\train\labels\101_jpg.rf.933f3c8c0396d6aaf7b318c39a0d5aca.txt
# ✅ Updated: CrossWalk_Copy\train\labels\101_jpg.rf.b0ffa2fc3e5b49cf89a108cc9cbaf5f6.txt
# ✅ Updated: CrossWalk_Copy\train\labels\101_jpg.rf.e0d64d9ccdf86dc8cc00fbd886eb1b7d.txt
# ✅ Updated: CrossWalk_Copy\train\labels\101_jpg.rf.f23233609a1a172695cc0a1f60aa12c0.txt
# ✅ Updated: CrossWalk_Copy\train\labels\102_jpg.rf.b0f812110d9d2bd2ce64489dc68bcff8.txt
# ✅ Updated: CrossWalk_Copy\train\labels\102_jpg.rf.eab33090de7733281a1c8695ff8d2968.txt
# ✅ Updated: CrossWalk_Copy\train\labels\102_jpg.rf.f776526d185bcb5e8ff067be7564f516.txt
# ✅ Updated: CrossWalk_Copy\train\labels\103_jpg.rf.14e02c03007c28c9aa5e9b7f75c55519.txt
# ✅ Updated: CrossWalk_Copy\train\labels\103_jpg.rf.1dc85e75f8b0070c09e3c8d57b26db53.txt
# ✅ Updated: CrossWalk_Copy\train\labels\103_jpg.rf.30ac4405682e8b12f19bb923d5cc5823.txt
# ✅ Updated: CrossWalk_Copy\train\labels\103_jpg.rf.bcdf80d92bd19def51252394cc4c173f.txt
# ✅ Updated: CrossWalk_Copy\train\labels\103_jpg.rf.ceb22a123022c699bf76448221ec13ff.txt
# ✅ Updated: CrossWalk_Copy\train\labels\103_jpg.rf.f82e940f46a6a14cda73693dc4365dd0.txt
# ✅ Updated: CrossWalk_Copy\train\labels
txt
# ✅ Updated: CrossWalk_Copy\valid\labels\t-10-_jpg.rf.9da0136d998779d926a452589d87e79b.txt
# ✅ Updated: CrossWalk_Copy\valid\labels\t-3-_jpg.rf.b90d5e30d1d6b356acf4d3a09f94bebb.txt
# ✅ Updated: CrossWalk_Copy\test\labels\106_jpg.rf.c553e029cafd3a8b9d31a272fabe41dd.txt
# ✅ Updated: CrossWalk_Copy\test\labels\108_jpg.rf.cdf64d3556a4226d2f5f4b0b36cd5235.txt
# ✅ Updated: CrossWalk_Copy\test\labels\109_jpg.rf.221895bc52403922930f87c615acf7fd.txt
# ✅ Updated: CrossWalk_Copy\test\labels\109_jpg.rf.a8b0305ff87b99c40524ee4bcd5552b2.txt
# ✅ Updated: CrossWalk_Copy\test\labels\109_jpg.rf.e868910333e8c59f65413299e8b787c7.txt
# ✅ Updated: CrossWalk_Copy\test\labels\110_jpg.rf.3f9ada1a7d154be0c30386f9000af268.txt
# ✅ Updated: CrossWalk_Copy\test\labels\110_jpg.rf.f927be83aa086144abcebda992d8fc09.txt
# ✅ Updated: CrossWalk_Copy\test\labels\113_jpg.rf.fc88d4b9c9565548e5a1ce0348857808.txt
# ✅ Updated: CrossWalk_Copy\test\labels\114_jpg.rf.a2cd30ac2fda7f9fa003ddd10651a637.txt
# ✅ Updated: CrossWalk_Copy\test\labels\115_jpg.rf.8135943d71967d078791bf49578d6836.txt
# ✅ Updated: CrossWalk_Copy\test\labels\116_jpg.rf.cfc7634e3a356a0d8098f31b725a89db.txt
# ✅ Updated: CrossWalk_Copy\test\labels\116_jpg.rf.db2937e4d780f6e4e53e0f5558278b8c.txt
# ✅ Updated: CrossWalk_Copy\test\labels\120_jpg.rf.7ddb34fe1e4fa357df88b852db53a7b5.txt
# ✅ Updated: CrossWalk_Copy\test\labels\121_jpg.rf.3680632467b7cef296962b80dd79e35f.txt
# ✅ Updated: CrossWalk_Copy\test\labels\125_jpg.rf.b6deff3bec17cac23f6c8fc2b39fc6b9.txt
# ✅ Updated: CrossWalk_Copy\test\labels\127_jpg.rf.13432fe7ef69ae5e0e450b45db3c04ce.txt
# ✅ Updated: CrossWalk_Copy\test\labels\128_jpg.rf.d1f351bb36208fea152b660a11629c3a.txt
# ✅ Updated: CrossWalk_Copy\test\labels\12_jpg.rf.f8770fd8c835abaad2dbf90c8f8e0d71.txt
# ✅ Updated: CrossWalk_Copy\test\labels\130_jpg.rf.366963d8df1fdb5ce5c83368afb04b39.txt
# ✅ Updated: CrossWalk_Copy\test\labels\131_jpg.rf.b90ea561395e96c5c82b71c56a5050de.txt
# ✅ Updated: CrossWalk_Copy\test\labels\133_jpg.rf.15676d8147754864a7ce348d9eb7da78.txt
# ✅ Updated: CrossWalk_Copy\test\labels\137_jpg.rf.7407eb870baffbedd6228f0550c71f78.txt
# ✅ Updated: CrossWalk_Copy\test\labels\149_jpg.rf.98fd1d8f3a3ffec8f7eaca13afeab3bd.txt
# ✅ Updated: CrossWalk_Copy\test\labels\151_jpg.rf.46d1918058f30e90c4df7f8b0e8e4a24.txt
# ✅ Updated: CrossWalk_Copy\test\labels\157_jpg.rf.ea7c9036accfcda849d4539c679540a6.txt
# ✅ Updated: CrossWalk_Copy\test\labels\158_jpg.rf.78c6451faf9d87d160ccfa03de943d55.txt
# ✅ Updated: CrossWalk_Copy\test\labels\158_jpg.rf.ded70af4c404f1b95508ca61093ce9af.txt
# ✅ Updated: CrossWalk_Copy\test\labels\15_jpg.rf.31cf52a0149c0ce8392a7ead14d303d4.txt
# ✅ Updated: CrossWalk_Copy\test\labels\15_jpg.rf.479e33b40c3591c53b1e87fa7ae424bd.txt
# ✅ Updated: CrossWalk_Copy\test\labels\162_jpg.rf.0ae10047ea8b4d2bca5f3554991d6ab8.txt
# ✅ Updated: CrossWalk_Copy\test\labels\162_jpg.rf.5550a289e0c2adefd5b93903ac35c8bb.txt
# ✅ Updated: CrossWalk_Copy\test\labels\162_jpg.rf.6ecac33e46a4c303bbfd5fcca454e6dd.txt
# ✅ Updated: CrossWalk_Copy\test\labels\164_jpg.rf.ce4d13e7079e376d531ab1f6d98d3678.txt
# ✅ Updated: CrossWalk_Copy\test\labels\165_jpg.rf.19c38b9236c1b8e60bf78dae31e4e657.txt
# ✅ Updated: CrossWalk_Copy\test\labels\166_jpg.rf.7455461d9a3b6a51fac3c0655eb38be2.txt
# ✅ Updated: CrossWalk_Copy\test\labels\170_jpg.rf.ee720da9f721be1e992b044e83367120.txt
# ✅ Updated: CrossWalk_Copy\test\labels\171_jpg.rf.e653cb6e1f52ba488c653467fd88ca63.txt
# ✅ Updated: CrossWalk_Copy\test\labels\172_jpg.rf.3c91e8c1e8673ffe7d2f73dc6ea69552.txt
# ✅ Updated: CrossWalk_Copy\test\labels\173_jpg.rf.27ccba8ca02db42672656d20470c2ec3.txt
# ✅ Updated: CrossWalk_Copy\test\labels\181_jpg.rf.0f648ba2ae7364349e2aaf5d1c533688.txt
# ✅ Updated: CrossWalk_Copy\test\labels\181_jpg.rf.a19b2c6aebe4802d6701ea1beb61c5e4.txt
# ✅ Updated: CrossWalk_Copy\test\labels\186_jpg.rf.7463225e8ea1a188c6b41bf8947fe2a3.txt
# ✅ Updated: CrossWalk_Copy\test\labels\187_jpg.rf.268a994741e08a5534b457f40b4350d3.txt
# ✅ Updated: CrossWalk_Copy\test\labels\18_jpg.rf.ee54b512f871b1dd9339ef1c0a5479b7.txt
# ✅ Updated: CrossWalk_Copy\test\labels\190_jpg.rf.32b311183a077bb86b2d910af1aa83d4.txt
# ✅ Updated: CrossWalk_Copy\test\labels\192_jpg.rf.03e18f5e845d74d3e73c059c9f85f0ae.txt
# ✅ Updated: CrossWalk_Copy\test\labels\194_jpg.rf.2a7915cc1f0bafc9da42ff6e7cf69664.txt
# ✅ Updated: CrossWalk_Copy\test\labels\194_jpg.rf.634a9ee2771f31a8a170c6065627e100.txt
# ✅ Updated: CrossWalk_Copy\test\labels\26_jpg.rf.0582d0ed9339fa9e0395728fe0f1723e.txt
# ✅ Updated: CrossWalk_Copy\test\labels\27_jpg.rf.54d21b7930f52dde110cbac9f654f532.txt
# ✅ Updated: CrossWalk_Copy\test\labels\30_jpg.rf.5f9cc89e8e165d5481ec0fb2398be387.txt
# ✅ Updated: CrossWalk_Copy\test\labels\30_jpg.rf.cacc63a84e40447c226503b5a14625fe.txt
# ✅ Updated: CrossWalk_Copy\test\labels\30_jpg.rf.fd5c40d5255dd5bf65078c7b521b47b7.txt
# ✅ Updated: CrossWalk_Copy\test\labels\33_jpg.rf.ed60266d5a16d98bb730155d2b67ea7f.txt
# ✅ Updated: CrossWalk_Copy\test\labels\36_jpg.rf.bba8ef6d4037a3b072b7a1855b50a517.txt
# ✅ Updated: CrossWalk_Copy\test\labels\37_jpg.rf.35cc20035a52981db89a6e542cb85990.txt
# ✅ Updated: CrossWalk_Copy\test\labels\41_jpg.rf.6c8def0fd832e4c90d3745916482badd.txt
# ✅ Updated: CrossWalk_Copy\test\labels\4_jpg.rf.1bf411970d695d2d9657f433c8d8dfde.txt
# ✅ Updated: CrossWalk_Copy\test\labels\54_jpg.rf.007334c99f31dd0f30de62b2f16895e2.txt
# ✅ Updated: CrossWalk_Copy\test\labels\54_jpg.rf.7786e02f8b3db88c16a8ee55750cd583.txt
# ✅ Updated: CrossWalk_Copy\test\labels\57_jpg.rf.19c368880a3d333150a70e6d08378784.txt
# ✅ Updated: CrossWalk_Copy\test\labels\57_jpg.rf.2962b34d968a91620242784d6a88ba37.txt
# ✅ Updated: CrossWalk_Copy\test\labels\5_jpg.rf.dacc6f49b3dccc30df5670000e2eadd9.txt
# ✅ Updated: CrossWalk_Copy\test\labels\61_jpg.rf.b1b0f0e0935772f9d467b13919e7d00f.txt
# ✅ Updated: CrossWalk_Copy\test\labels\66_jpg.rf.feb56a255985cd7ee55d4b8805989a3f.txt
# ✅ Updated: CrossWalk_Copy\test\labels\67_jpg.rf.3215d4cf043812277b74ccc9c161bed6.txt
# ✅ Updated: CrossWalk_Copy\test\labels\69_jpg.rf.7649c9cb71e7b1314a6d3632744f92ba.txt
# ✅ Updated: CrossWalk_Copy\test\labels\69_jpg.rf.aae5618497de959ed6a2daa5bc04d8cc.txt
# ✅ Updated: CrossWalk_Copy\test\labels\70_jpg.rf.d52ee994c2e861368e3878092f4b769a.txt
# ✅ Updated: CrossWalk_Copy\test\labels\79_jpg.rf.285aac7fb185b127685bf9d8bca13e1c.txt
# ✅ Updated: CrossWalk_Copy\test\labels\7_jpg.rf.0e60963db1689bbdd3ca0ce57725ff3a.txt
# ✅ Updated: CrossWalk_Copy\test\labels\7_jpg.rf.2863b2b734110d7f346f16a27d5ab5cd.txt
# ✅ Updated: CrossWalk_Copy\test\labels\83_jpg.rf.bdad3c43f0bfe2d8f77f943264a3b4e7.txt
# ✅ Updated: CrossWalk_Copy\test\labels\88_jpg.rf.f5387aee082885360b650efca24919a6.txt
# ✅ Updated: CrossWalk_Copy\test\labels\91_jpg.rf.197e96dac75a34e8e41580104b13cc20.txt
# ✅ Updated: CrossWalk_Copy\test\labels\93_jpg.rf.e7673a2c70759112f1b175f2171ca3ed.txt
# ✅ Updated: CrossWalk_Copy\test\labels\94_jpg.rf.bbf19d5b24e3ae2c5a6a20ad483e72de.txt
# ✅ Updated: CrossWalk_Copy\test\labels\99_jpg.rf.8f39111e1ab608cecb8742e34a5c7923.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_107_jpg.rf.112bc8dd85ed31dd63bead759a57a695.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_142_jpg.rf.ed9ba96dac19992fc8c6f64c941b5ad4.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_18_jpg.rf.e9f10ee4acbf1b81fe1fdd05c78c155e.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_23_jpg.rf.a0406858ea9af3aa03c41a8702993766.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_30_jpg.rf.fd2ff6b14bfc8b925ed58e77e25b007d.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_42_jpg.rf.0b64bdfcc8b19119be795f33755ba7bd.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_53_jpg.rf.76cbb3d52e8783c082a825256fa0838d.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_62_jpg.rf.e56e5d82aa3d1fdbeaf3fc23de83c6fa.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_66_jpg.rf.42a1683d037d6e085d167adb8f634d4a.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_6_jpg.rf.82fbaef259a2d7081a64ab289faefd75.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_73_jpg.rf.ec885b3768c1a5e254f35a4332cd9e11.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_82_jpg.rf.b7eecdf25d5550fc194c75209cf1ea72.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_83_jpg.rf.4c26c3bac96c1accc63117097dd710d4.txt
# ✅ Updated: CrossWalk_Copy\test\labels\c3_p1_97_jpg.rf.000754d910da2104524ae3b95a0b46f2.txt
# ✅ Updated: CrossWalk_Copy\test\labels\Cross-1015-_png_jpg.rf.8afa281f2bf11e199275eb5a036edc60.txt
# ✅ Updated: CrossWalk_Copy\test\labels\Cross-1026-_png_jpg.rf.5626fd0393a678b59d5491e948d1314d.txt
# ✅ Updated: CrossWalk_Copy\test\labels\Cross-1043-_png_jpg.rf.40dbc584113b4f8bb55ce629f350bb34.txt
# ✅ Updated: CrossWalk_Copy\test\labels\Cross-1054-_png_jpg.rf.019ca639d1cb02388dbafa8cf585b183.txt
# ✅ Updated: CrossWalk_Copy\test\labels\Cross-1065-_png_jpg.rf.ac915c3c263d049faf4fda823bfe27b2.txt
# ✅ Updated: CrossWalk_Copy\test\labels\Cross-1093-_png_jpg.rf.4bbe5687bfdad6550f46b035f545994b.txt
# ✅ Updated: CrossWalk_Copy\test\labels\KakaoTalk_20220320_162808517_07_jpg.rf.1e2a34d9fd4f3520658582fe6536e44a.txt
# ✅ Updated: CrossWalk_Copy\test\labels\KakaoTalk_20220320_162808517_09_jpg.rf.ec89326450804ca083505d863e09525a.txt
# ✅ Updated: CrossWalk_Copy\test\labels\KakaoTalk_20220320_162808517_jpg.rf.802c28045d1ebaa1594cf550d8a8bd55.txt
# ✅ Updated: CrossWalk_Copy\test\labels\t-1-_jpg.rf.10399af5ebd0c6c786dcc385bac203d5.txt
# 🎯 All labels updated successfully!

# %% [markdown]
# #to Merge dataset

# %%
import os
import shutil

# List of source folders
source_folders = ["traffic_light_v2i_yolov8", "CrossWalk_Copy"]

# Destination dataset path
dataset_base = "padestrian_traffic_light_and_crosswalk"
subfolders = ["train", "valid", "test"]

# Create dataset structure
for subfolder in subfolders:
    os.makedirs(os.path.join(dataset_base, subfolder, "images"), exist_ok=True)
    os.makedirs(os.path.join(dataset_base, subfolder, "labels"), exist_ok=True)

# Function to merge images and labels
def merge_data(data_type):
    dest_images = os.path.join(dataset_base, data_type, "images")
    dest_labels = os.path.join(dataset_base, data_type, "labels")

    for folder in source_folders:
        src_images = os.path.join(folder, data_type, "images")
        src_labels = os.path.join(folder, data_type, "labels")

        if os.path.exists(src_images):
            for file in os.listdir(src_images):
                shutil.copy(os.path.join(src_images, file), os.path.join(dest_images, file))

        if os.path.exists(src_labels):
            for file in os.listdir(src_labels):
                shutil.copy(os.path.join(src_labels, file), os.path.join(dest_labels, file))

# Merge train, valid, test data
for subfolder in subfolders:
    merge_data(subfolder)

print("✅ Dataset merged successfully!")
# Out:
# ✅ Dataset merged successfully!

# %%
# %pip install albumentations
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting albumentations
#   Using cached albumentations-2.0.5-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\welcome\appdata\roaming\python\python313\site-packages (from albumentations) (2.1.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\welcome\appdata\roaming\python\python313\site-packages (from albumentations) (1.14.1)
# Requirement already satisfied: PyYAML in c:\users\welcome\appdata\roaming\python\python313\site-packages (from albumentations) (6.0.2)
# Collecting pydantic>=2.9.2 (from albumentations)
#   Using cached pydantic-2.11.1-py3-none-any.whl.metadata (63 kB)
# Collecting albucore==0.0.23 (from albumentations)
#   Using cached albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations)
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\welcome\appdata\roaming\python\python313\site-packages (from albucore==0.0.23->albumentations) (3.12.3)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\welcome\appdata\roaming\python\python313\site-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9.2->albumentations)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\welcome\appdata\roaming\python\python313\site-packages (from pydantic>=2.9.2->albumentations) (2.33.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\welcome\appdata\roaming\python\python313\site-packages (from pydantic>=2.9.2->albumentations) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\welcome\appdata\roaming\python\python313\site-packages (from pydantic>=2.9.2->albumentations) (0.4.0)
# Using cached albumentations-2.0.5-py3-none-any.whl (290 kB)
# Using cached albucore-0.0.23-py3-none-any.whl (14 kB)
# Using cached opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl (39.4 MB)
# Using cached pydantic-2.11.1-py3-none-any.whl (442 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Installing collected packages: opencv-python-headless, annotated-types, pydantic, albucore, albumentations
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\welcome\\AppData\\Roaming\\Python\\Python313\\site-packages\\cv2\\cv2.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# DATA Augmentation code

import os
import cv2
import numpy as np
import albumentations as A
from albumentations.pytorch import ToTensorV2
import glob


# Define augmentation pipeline
augment = A.Compose([
    A.HorizontalFlip(p=0.5),
    # A.VerticalFlip(p=0.5),
    A.Rotate(limit=20, p=0.5),
    A.RandomBrightnessContrast(p=0.3),
    A.MotionBlur(p=0.2),
    A.Perspective(scale=(0.05, 0.1), p=0.3),
], bbox_params=A.BboxParams(format="yolo", label_fields=["class_labels"]))
dataset_base = "dataset_Copy"  # Base path

for split in ["train", "valid", "test"]:
    dataset_path = os.path.join(dataset_base, split)
    image_folder = os.path.join(dataset_path, "images")
    label_folder = os.path.join(dataset_path, "labels")
    augmented_folder = os.path.join(dataset_path, "augmented")

    # Create folders if they don't exist
    os.makedirs(os.path.join(augmented_folder, "images"), exist_ok=True)
    os.makedirs(os.path.join(augmented_folder, "labels"), exist_ok=True)

    # Get all image files
    image_files = glob.glob(os.path.join(image_folder, "*.jpg"))  # Change extension if needed

    for img_path in image_files:
        # Load image
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        height, width, _ = img.shape

        # Load corresponding label file
        label_path = os.path.join(label_folder, os.path.basename(img_path).replace(".jpg", ".txt"))
        if not os.path.exists(label_path):
            continue

        with open(label_path, "r") as f:
            labels = f.readlines()

        # Parse YOLO format labels (class x_center y_center width height)
        bboxes = []
        class_labels = []
        for line in labels:
            parts = line.strip().split()
            class_labels.append(int(parts[0]))  # Class ID
            bbox = list(map(float, parts[1:]))  # x_center, y_center, width, height
            if len(bbox) == 4:
                x, y, w, h = bbox
                if 0 <= x <= 1 and 0 <= y <= 1 and 0 <= w <= 1 and 0 <= h <= 1:
                    bboxes.append(bbox)

        # Perform Augmentation 5 times per image
        for i in range(5):
            augmented = augment(image=img, bboxes=bboxes, class_labels=class_labels)
            aug_img = augmented["image"]
            aug_bboxes = augmented["bboxes"]

            # Ensure bounding boxes are valid (Clip them to [0,1])
            aug_bboxes = np.clip(aug_bboxes, 0, 1)

            # Filter out invalid boxes
            valid_bboxes = []
            valid_classes = []
            for box, cls in zip(aug_bboxes, class_labels):
                if len(box) > 4:
                    continue
                x, y, w, h = box
                if 0 <= x <= 1 and 0 <= y <= 1 and 0 <= w <= 1 and 0 <= h <= 1:
                    valid_bboxes.append(box)
                    valid_classes.append(cls)

            if not valid_bboxes:
                continue  # Skip if no valid boxes

            # Save Augmented Image
            aug_img_filename = f"{os.path.splitext(os.path.basename(img_path))[0]}_aug_{i}.jpg"
            aug_img_path = os.path.join(augmented_folder, "images", aug_img_filename)
            cv2.imwrite(aug_img_path, cv2.cvtColor(aug_img, cv2.COLOR_RGB2BGR))

            # Save Augmented Label
            aug_label_filename = aug_img_filename.replace(".jpg", ".txt")
            aug_label_path = os.path.join(augmented_folder, "labels", aug_label_filename)

            with open(aug_label_path, "w") as f:
                for bbox, cls in zip(valid_bboxes, valid_classes):
                    f.write(f"{cls} {' '.join(map(str, bbox))}\n")

    print(f"Augmentation completed for {split} set! 🚀")

print("All dataset splits augmented successfully! ✅")
# Out:
# Augmentation completed for train set! 🚀
# Augmentation completed for valid set! 🚀
# Augmentation completed for test set! 🚀
# All dataset splits augmented successfully! ✅

# %%
# Python script to delete .txt files in the labels folder if their corresponding .jpg images do not exist in the images folder.

import os

# Define folder paths
images_folder = "dataset_Copy/valid/images"
labels_folder = "dataset_Copy/valid/labels"

# Get the set of image names without extension
image_names = {os.path.splitext(f)[0] for f in os.listdir(images_folder) if f.endswith(".jpg")}

# Iterate through label files and delete unmatched ones
for label_file in os.listdir(labels_folder):
    # if label_file.endswith(".txt"):
    label_name = os.path.splitext(label_file)[0]
    if label_name not in image_names:
        label_path = os.path.join(labels_folder, label_file)
        os.remove(label_path)
        print(f"Deleted: {label_path}")

print("Cleanup complete.")
# Out:
# Deleted: dataset_Copy/valid/labels\-_png.rf.3489689e759452e8a5ffb8490f8af750_aug_0.txt
# Deleted: dataset_Copy/valid/labels\-_png.rf.3489689e759452e8a5ffb8490f8af750_aug_1.txt
# Deleted: dataset_Copy/valid/labels\-_png.rf.3489689e759452e8a5ffb8490f8af750_aug_2.txt
# Deleted: dataset_Copy/valid/labels\-_png.rf.3489689e759452e8a5ffb8490f8af750_aug_3.txt
# Deleted: dataset_Copy/valid/labels\-_png.rf.3489689e759452e8a5ffb8490f8af750_aug_4.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1503_jpg.rf.f26e040fcd71bbc5a5e4b46c65881dd2_aug_0.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1503_jpg.rf.f26e040fcd71bbc5a5e4b46c65881dd2_aug_1.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1503_jpg.rf.f26e040fcd71bbc5a5e4b46c65881dd2_aug_2.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1503_jpg.rf.f26e040fcd71bbc5a5e4b46c65881dd2_aug_3.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1503_jpg.rf.f26e040fcd71bbc5a5e4b46c65881dd2_aug_4.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1507_jpg.rf.a1f030d434f82052e60856a71c7c7f87_aug_0.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1507_jpg.rf.a1f030d434f82052e60856a71c7c7f87_aug_1.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1507_jpg.rf.a1f030d434f82052e60856a71c7c7f87_aug_2.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1507_jpg.rf.a1f030d434f82052e60856a71c7c7f87_aug_3.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1507_jpg.rf.a1f030d434f82052e60856a71c7c7f87_aug_4.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1720_jpg.rf.905cae41d0786d65020f7a84da072ebc_aug_0.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1720_jpg.rf.905cae41d0786d65020f7a84da072ebc_aug_1.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1720_jpg.rf.905cae41d0786d65020f7a84da072ebc_aug_2.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1720_jpg.rf.905cae41d0786d65020f7a84da072ebc_aug_3.txt
# Deleted: dataset_Copy/valid/labels\crosswalk_1720_jpg.rf.905cae41d0786d65020f7a84da072ebc_aug_4.txt
# Deleted: dataset_Copy/valid/labels\images-57-_jpg.rf.a40a4704d8e10c61799d1b28a762f146_aug_0.txt
# Deleted: dataset_Copy/valid/labels\images-57-_jpg.rf.a40a4704d8e10c61799d1b28a762f146_aug_1.txt
# Deleted: dataset_Copy/valid/labels\images-57-_jpg.rf.a40a4704d8e10c61799d1b28a762f146_aug_2.txt
# Deleted: dataset_Copy/valid/labels\images-57-_jpg.rf.a40a4704d8e10c61799d1b28a762f146_aug_3.txt
# Deleted: dataset_Copy/valid/labels\images-57-_jpg.rf.a40a4704d8e10c61799d1b28a762f146_aug_4.txt
# Cleanup complete.

# %%
import os

# Define folder paths
images_folder = "CrossWalk - Copy/train/labels"
labels_folder = "CrossWalk - Copy/train/images"

# Get the set of image names without extension
image_names = {os.path.splitext(f)[0] for f in os.listdir(images_folder) if f.endswith(".txt")}

# Iterate through label files and delete unmatched ones
for label_file in os.listdir(labels_folder):
    # if label_file.endswith(".txt"):
    label_name = os.path.splitext(label_file)[0]
    if label_name not in image_names:
        label_path = os.path.join(labels_folder, label_file)
        os.remove(label_path)
        print(f"Deleted: {label_path}")

print("Cleanup complete.")
# Out:
# Deleted: CrossWalk - Copy/train/images\31_jpg.rf.e45fe4d58403bed7ea54aea21b792afb - Copy.jpg
# Deleted: CrossWalk - Copy/train/images\33_jpg.rf.874022b75f6803ca30f2a0a4e9de6d58 - Copy.jpg
# Deleted: CrossWalk - Copy/train/images\7_jpg.rf.f5bce224c57f019980d1b5dc10a56e4d - Copy.jpg
# Cleanup complete.
